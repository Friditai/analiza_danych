# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
path = "./data/StressLevelDataset.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %%
unchanged_df = df.copy()

# %% [markdown]
# **Sprawdzenie korelacji**

# %%
# Obliczanie korelacji między różnymi cechami
correlation = unchanged_df.corr()
# Ustawienie większego rozmiaru heatmapy
plt.figure(figsize=(15, 12))
# Tworzenie heatmapy korelacji
sns.heatmap(correlation, annot=True,  annot_kws={"size": 12})
# Wyświetlenie wykresu
plt.show()

# %% [markdown]
# **Sprawdzenie unikatowych wartości**

# %%
df['blood_pressure'].unique()
# Out:
# array([1, 3, 2])

# %%
blood_pressure_map = {1: 'low', 2: 'medium', 3: 'high'}

# %%
df['blood_pressure_level'] = df['blood_pressure'].replace(blood_pressure_map)

# %%
df[['blood_pressure','blood_pressure_level']].head(10)
# Out:
#    blood_pressure blood_pressure_level
# 0               1                  low
# 1               3                 high
# 2               1                  low
# 3               3                 high
# 4               3                 high
# 5               3                 high
# 6               2               medium
# 7               3                 high
# 8               1                  low
# 9               3                 high

# %%
df['stress_level'].unique()
# Out:
# array([1, 2, 0])

# %%
stress_level_map = {0: 'low', 1: 'medium', 2: 'high'}

# %%
df['stress_intensity'] = df['stress_level'].replace(stress_level_map)

# %%
df[['stress_level','stress_intensity']].head(10)
# Out:
#    stress_level stress_intensity
# 0             1           medium
# 1             2             high
# 2             1           medium
# 3             2             high
# 4             1           medium
# 5             2             high
# 6             0              low
# 7             2             high
# 8             1           medium
# 9             1           medium

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  study_load  teacher_student_relationship  \
# ...

# %% [markdown]
# **Wpływ poziomu odczuwanego stresu na jakość snu**

# %%
# Tworzenie wykresu skrzypcowego pokazującego rozkład i gęstość poziomu odczuwanego stresu od jakości snu
sns.violinplot(x='stress_intensity', y='sleep_quality', data=df, order=['low', 'medium', 'high'])
# Out:
# <Axes: xlabel='stress_intensity', ylabel='sleep_quality'>

# %% [markdown]
# Im mniejsza intensywność przeżywanego stresu tym lepsza jakość snu.

# %% [markdown]
# **Wpływ poziomu odczuwanego stresu na pojawienie się depresji**

# %%
sns.boxplot(x='stress_intensity', y='depression', data=df, order=['low', 'medium', 'high'])
# Out:
# <Axes: xlabel='stress_intensity', ylabel='depression'>

# %% [markdown]
# Im większa intensywność przeżywanego stresu tym większe ryzyko pojawienia się poważnej depresji.

# %%
df['sleep_quality'].unique()
# Out:
# array([2, 1, 5, 4, 3, 0])

# %%
sns.countplot(x='stress_intensity', data=df, order=['low', 'medium', 'high'])
# Out:
# <Axes: xlabel='stress_intensity', ylabel='count'>

# %%
df['stress_intensity'].value_counts()
# Out:
# stress_intensity
# low       373
# high      369
# medium    358
# Name: count, dtype: int64

# %%
df_grouped = df.groupby('academic_performance')[['self_esteem', 'anxiety_level', 'living_conditions', 'depression']].mean()

# %%
df_grouped.head(10)
# Out:
#                       self_esteem  anxiety_level  living_conditions  \
# academic_performance
# 0                       16.250000      10.392857           2.571429
# 1                        8.524324      16.718919           1.708108
# 2                       14.433908      14.011494           2.094828
# 3                       18.786982      11.455621           2.514793
# 4                       24.819149       5.090426           3.329787
# 5                       25.598901       5.587912           3.307692
#
#                       depression
# academic_performance
# 0                      12.714286
# 1                      20.118919
# 2                      15.551724
# 3                      12.550296
# 4                       6.494681
# 5                       5.379121

# %%
sns.lineplot(x='academic_performance', y='self_esteem', data=df_grouped)
# Out:
# <Axes: xlabel='academic_performance', ylabel='self_esteem'>

# %%
sns.scatterplot(x='academic_performance', y='depression', data=df_grouped)
# Out:
# <Axes: xlabel='academic_performance', ylabel='depression'>

# %%
df_grouped2 = df.groupby('study_load')[['study_load', 'future_career_concerns', 'anxiety_level', 'stress_level', 'depression']].median()

# %%
df_grouped2.head(10)
# Out:
#             study_load  future_career_concerns  anxiety_level  stress_level  \
# study_load
# 0                  0.0                     3.0            8.0           1.0
# 1                  1.0                     1.0            4.0           0.0
# 2                  2.0                     2.0            9.0           1.0
# 3                  3.0                     3.0           13.0           1.0
# 4                  4.0                     4.0           17.0           2.0
# 5                  5.0                     4.0           17.0           2.0
#
#             depression
# study_load
# 0                 13.0
# 1                  5.0
# 2                  9.0
# 3                 14.0
# 4                 20.0
# 5                 21.0

# %%
fig = px.scatter_3d(df_grouped2, x='study_load', y='future_career_concerns', z='stress_level',
                    title='Wpływ przeciążenia nauką i obaw o przyszłą karierę zawodową na poziom stresu',
                    size_max=6, color='stress_level', opacity=0.7, color_continuous_scale='Viridis')

fig.update_layout(autosize=False, width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()
